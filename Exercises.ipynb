# %% [markdown]
# # Wind Statistics

# %% [markdown]
# ### Introduction:
#
# The data have been modified to contain some missing values, identified by NaN.
# Using pandas should make this exercise
# easier, in particular for the bonus question.
#
# You should be able to perform all of these operations without using
# a for loop or other looping construct.
#
#
# 1. The data in 'wind.data' has the following format:

# %%
"""
Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL
61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04
61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83
61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
"""
# Out:
# '\nYr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL\n61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04\n61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83\n61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71\n'

# %% [markdown]
#    The first three columns are year, month and day.  The
#    remaining 12 columns are average windspeeds in knots at 12
#    locations in Ireland on that day.
#
#    More information about the dataset go [here](wind.desc).

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import datetime
import ssl

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data)

# %% [markdown]
# ### Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.

# %%
ssl._create_default_https_context=ssl._create_unverified_context

# parse_dates gets 0, 1, 2 columns and parses them as the index
data_url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
data = pd.read_csv(data_url, sep = "\s+", parse_dates = [[0,1,2]]) 
data.head()
# Out:
# /var/folders/fk/2g92d3b90_x_95jtdfyy0m4w0000gn/T/ipykernel_41831/4173104772.py:5: FutureWarning: Support for nested sequences for 'parse_dates' in pd.read_csv is deprecated. Combine the desired columns with pd.to_datetime after parsing instead.
#   data = pd.read_csv(data_url, sep = "\s+", parse_dates = [[0,1,2]])
# /var/folders/fk/2g92d3b90_x_95jtdfyy0m4w0000gn/T/ipykernel_41831/4173104772.py:5: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv(data_url, sep = "\s+", parse_dates = [[0,1,2]])
#     Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# ...

# %% [markdown]
# ### Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.

# %%
def year_min_sto(x):
    year = x.replace(year=x.year -100)
    return year
data['Yr_Mo_Dy'] = data['Yr_Mo_Dy'].apply(year_min_sto)
# data
# df['adjusted_datetime'] = df['datetime'].apply(lambda x: x.replace(year=x.year - 100))
# data = data.drop(columns='Yr_Mo_Dy')

# data.rename(columns={'Yr_Mo_Dy\t':'Yr_Mo_Dy'})
data
# Out:
#        Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB    CLA  \
# 0    1961-01-01  15.04  14.96  13.17   9.29    NaN   9.87  13.67  10.25
# 1    1961-01-02  14.71    NaN  10.83   6.50  12.62   7.67  11.50  10.04
# 2    1961-01-03  18.50  16.88  12.33  10.13  11.17   6.17  11.25    NaN
# 3    1961-01-04  10.58   6.63  11.75   4.58   4.54   2.88   8.63   1.79
# 4    1961-01-05  13.33  13.25  11.42   6.17  10.71   8.21  11.92   6.54
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6569 1878-12-27  17.58  16.96  17.62   8.08  13.21  11.67  14.46  15.59
# 6570 1878-12-28  13.21   5.46  13.46   5.00   8.12   9.42  14.33  16.25
# 6571 1878-12-29  14.00  10.29  14.42   8.71   9.71  10.54  19.17  12.46
# 6572 1878-12-30  18.50  14.04  21.29   9.13  12.75   9.71  18.08  12.87
# 6573 1878-12-31  20.33  17.41  27.29   9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 0     10.83  12.58  18.50  15.04
# 1      9.79   9.67  17.54  13.83
# ...

# %% [markdown]
# ### Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].

# %%
data = data.set_index(data.Yr_Mo_Dy)
# data = data.drop(columns='Yr_Mo_Dy')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 6574 entries, 1961-01-01 to 1878-12-31
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Yr_Mo_Dy  6574 non-null   datetime64[ns]
#  1   RPT       6568 non-null   float64
#  2   VAL       6571 non-null   float64
#  3   ROS       6572 non-null   float64
#  4   KIL       6569 non-null   float64
#  5   SHA       6572 non-null   float64
#  6   BIR       6574 non-null   float64
#  7   DUB       6571 non-null   float64
#  8   CLA       6572 non-null   float64
#  9   MUL       6571 non-null   float64
#  10  CLO       6573 non-null   float64
#  11  BEL       6574 non-null   float64
#  12  MAL       6570 non-null   float64
# dtypes: datetime64[ns](1), float64(12)
# memory usage: 719.0 KB

# %% [markdown]
# ### Step 6. Compute how many values are missing for each location over the entire record.
# #### They should be ignored in all calculations below.

# %%
data.isnull().sum()
# Out:
# Yr_Mo_Dy    0
# RPT         6
# VAL         3
# ROS         2
# KIL         5
# SHA         2
# BIR         0
# DUB         3
# CLA         2
# MUL         3
# CLO         1
# BEL         0
# MAL         4
# dtype: int64

# %% [markdown]
# ### Step 7. Compute how many non-missing values there are in total.

# %%
data.count()
data.count()
data.count()
data.count()
data.count()
# Out:
# Yr_Mo_Dy    6574
# RPT         6568
# VAL         6571
# ROS         6572
# KIL         6569
# SHA         6572
# BIR         6574
# DUB         6571
# CLA         6572
# MUL         6571
# CLO         6573
# BEL         6574
# MAL         6570
# dtype: int64

# %% [markdown]
# ### Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
# #### A single number for the entire dataset.

# %%
abc = pd.DataFrame(data.iloc[:,1:].mean())
abc = abc.rename(columns={0:'mean'})
abc
# Out:
#           mean
# RPT  12.362987
# VAL  10.644314
# ROS  11.660526
# KIL   6.306468
# SHA  10.455834
# BIR   7.092254
# DUB   9.797343
# CLA   8.495053
# MUL   8.493590
# CLO   8.707332
# BEL  13.121007
# MAL  15.599079

# %%
abc.mean()
# Out:
# mean    10.227982
# dtype: float64

# %% [markdown]
# ### Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days
#
# #### A different set of numbers for each location.

# %%
loc_stats = pd.DataFrame(data.agg({'min','max','mean'}).round(2))
loc_stats["Yr_Mo_Dy"] = loc_stats["Yr_Mo_Dy"].dt.round("min")
# .dt.strftime("%Y-%m-%d %H:%M:%S.%f").str[:-4]
loc_stats
# Out:
#                 Yr_Mo_Dy    RPT    VAL    ROS    KIL    SHA    BIR    DUB  \
# mean 1947-10-11 10:31:00  12.36  10.64  11.66   6.31  10.46   7.09   9.80
# max  1974-12-31 00:00:00  35.80  33.37  33.84  28.46  37.54  26.16  30.37
# min  1875-01-01 00:00:00   0.67   0.21   1.50   0.00   0.13   0.00   0.00
#
#         CLA    MUL    CLO    BEL    MAL
# mean   8.50   8.49   8.71  13.12  15.60
# max   31.08  25.88  28.21  42.38  42.54
# min    0.00   0.00   0.04   0.13   0.67

# %% [markdown]
# ### Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day.
#
# #### A different set of numbers for each day.

# %%
day_stats = pd.DataFrame()
day_stats['min'] = data.drop(columns='Yr_Mo_Dy').min(axis=1)  # min
day_stats['max'] = data.drop(columns='Yr_Mo_Dy').max(axis=1)  # max
day_stats['mean'] = data.drop(columns='Yr_Mo_Dy').mean(axis=1)  # mean
day_stats['std'] = data.drop(columns='Yr_Mo_Dy').std(axis=1)  # standard deviation
day_stats
# Out:
#              min    max       mean       std
# Yr_Mo_Dy
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1878-12-27  8.08  40.08  16.708333  7.868076
# 1878-12-28  5.00  41.46  15.150000  9.687857
# 1878-12-29  8.71  29.58  14.890000  5.756836
# 1878-12-30  9.13  28.79  15.367500  5.540437
# 1878-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# ### Step 11. Find the average windspeed in January for each location.
# #### Treat January 1961 and January 1962 both as January.

# %%
# loc_avg = pd.DataFrame()
# loc_avg['min'] = data.drop(columns='Yr_Mo_Dy').min(axis=0)  # min
# loc_avg['max'] = data.drop(columns='Yr_Mo_Dy').max(axis=0)  # max
# loc_avg['mean'] = data.drop(columns='Yr_Mo_Dy').mean(axis=0)  # mean
# loc_avg['std'] = data.drop(columns='Yr_Mo_Dy').std(axis=0)  # standard deviation
# loc_avg
data.loc[data.index.monxth == 1].mean()
# Out:
# Yr_Mo_Dy    1947-04-27 20:00:00
# RPT                   14.847325
# VAL                    12.91456
# ROS                   13.299624
# KIL                    7.199498
# SHA                   11.667734
# BIR                    8.054839
# DUB                   11.819355
# CLA                    9.512047
# MUL                    9.543208
# CLO                   10.053566
# BEL                    14.55052
# MAL                   18.028763
# dtype: object

# %% [markdown]
# ### Step 12. Downsample the record to a yearly frequency for each location.

# %%
# data.loc[data.index.year].mean()
data.groupby(data.index.to_period('A')).mean().round(2)
# Out:
# /var/folders/fk/2g92d3b90_x_95jtdfyy0m4w0000gn/T/ipykernel_41831/221365272.py:2: FutureWarning: 'A' is deprecated and will be removed in a future version, please use 'Y' instead.
#   data.groupby(data.index.to_period('A')).mean().round(2)
#                     Yr_Mo_Dy    RPT    VAL    ROS   KIL    SHA   BIR    DUB  \
# Yr_Mo_Dy
# 1875     1875-07-02 00:00:00  12.01  10.29  11.56  5.27   9.19  5.67   8.56
# 1876     1876-07-01 12:00:00  11.74  10.20  10.76  5.11   8.85  6.31   9.15
# 1877     1877-07-02 00:00:00  13.10  11.14  12.63  6.07  10.00  8.59  11.52
# 1878     1878-07-02 00:00:00  12.50  11.04  11.38  6.08  10.17  7.65   9.49
# 1961     1961-07-02 00:00:00  12.30  10.35  11.36  6.96  10.88  7.73   9.73
# 1962     1962-07-02 00:00:00  12.25  10.11  11.73  6.96  10.66  7.39  11.02
# 1963     1963-07-02 00:00:00  12.81  10.84  12.54  7.33  11.72  8.43  11.08
# 1964     1964-07-01 12:00:00  12.36  10.92  12.10  6.79  11.45  7.57  10.26
# ...

# %% [markdown]
# ### Step 13. Downsample the record to a monthly frequency for each location.

# %%
